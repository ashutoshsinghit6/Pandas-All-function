# %%
import pandas as pd

# %%
df=pd.read_csv("F:\\data\\pandas_tutorial_read.csv",header=1)
df
# Out:
#      2018-01-01 00:01:01;read;country_7;2458151261;SEO;North America  \
# 0     2018-01-01 00:03:20;read;country_7;2458151262;...
# 1     2018-01-01 00:04:01;read;country_7;2458151263;...
# 2     2018-01-01 00:04:02;read;country_7;2458151264;...
# 3     2018-01-01 00:05:03;read;country_8;2458151265;...
# 4     2018-01-01 00:05:42;read;country_6;2458151266;...
# ...                                                 ...
# 1789  2018-01-01 23:57:14;read;country_2;2458153051;...
# 1790  2018-01-01 23:58:33;read;country_8;2458153052;...
# 1791  2018-01-01 23:59:36;read;country_6;2458153053;...
# 1792  2018-01-01 23:59:36;read;country_7;2458153054;...
# 1793  2018-01-01 23:59:38;read;country_5;2458153055;...
#
#       Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5  Unnamed: 6  \
# 0            NaN         NaN         NaN         NaN         NaN         NaN
# 1            NaN         NaN         NaN         NaN         NaN         NaN
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-00cf07b74dcd> in <module>
# ----> 1 df
#
# NameError: name 'df' is not defined

# %%
df.tail
# Out:
# <bound method NDFrame.tail of      2018-01-01 00:01:01;read;country_7;2458151261;SEO;North America
# 0     2018-01-01 00:03:20;read;country_7;2458151262;...
# 1     2018-01-01 00:04:01;read;country_7;2458151263;...
# 2     2018-01-01 00:04:02;read;country_7;2458151264;...
# 3     2018-01-01 00:05:03;read;country_8;2458151265;...
# 4     2018-01-01 00:05:42;read;country_6;2458151266;...
# ...                                                 ...
# 1789  2018-01-01 23:57:14;read;country_2;2458153051;...
# 1790  2018-01-01 23:58:33;read;country_8;2458153052;...
# 1791  2018-01-01 23:59:36;read;country_6;2458153053;...
# 1792  2018-01-01 23:59:36;read;country_7;2458153054;...
# 1793  2018-01-01 23:59:38;read;country_5;2458153055;...
#
# [1794 rows x 1 columns]>

# %%
import pandas as pd

# %%
dff=pd.read_csv("F:\\data\\SalesJan2009.csv",header=1)

# %%
dff.sort_value("Latitude")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-49-0932d8e97b78> in <module>
# ----> 1 dff.sort_value("Latitude")
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5178                 return self[name]
# -> 5179             return object.__getattribute__(self, name)
#    5180
#    5181     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'sort_value'

# %%
dff.sort_value("Latitude")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-51-4a981ecf00d0> in <module>
# ----> 1 dff.sort_value("Latitude")
#       2
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5178                 return self[name]
# -> 5179             return object.__getattribute__(self, name)
#    5180
#    5181     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'sort_value'

# %%
dff.describe()
# Out:
#          Latitude   Longitude
# count  998.000000  998.000000
# mean    39.015705  -41.337820
# std     19.508572   67.389479
# min    -41.465000 -159.485280
# 25%     35.816944  -87.991670
# 50%     42.320695  -73.730695
# 75%     51.050000    4.916667
# max     64.837780  174.766667

# %%
dff["price",axis=1,inplace=True]
# Out:
#   File "<ipython-input-24-631ece11e4d9>", line 1
#     dff["price",axis=1,inplace=True]
#                     ^
# SyntaxError: invalid syntax

# %%
import os

# %%
print(os.getcwd())
# Out:
# C:\Users\hp world

# %%
import pandas as pd

# %%
df=pd.read_csv("F:\\data\\pandas_tutorial_read.csv")
df
# Out:
#                                                       0   1   2   3   4   5  \
# 0     2018-01-01 00:01:01;read;country_7;2458151261;... NaN NaN NaN NaN NaN
# 1     2018-01-01 00:03:20;read;country_7;2458151262;... NaN NaN NaN NaN NaN
# 2     2018-01-01 00:04:01;read;country_7;2458151263;... NaN NaN NaN NaN NaN
# 3     2018-01-01 00:04:02;read;country_7;2458151264;... NaN NaN NaN NaN NaN
# 4     2018-01-01 00:05:03;read;country_8;2458151265;... NaN NaN NaN NaN NaN
# ...                                                 ...  ..  ..  ..  ..  ..
# 1790  2018-01-01 23:57:14;read;country_2;2458153051;... NaN NaN NaN NaN NaN
# 1791  2018-01-01 23:58:33;read;country_8;2458153052;... NaN NaN NaN NaN NaN
# 1792  2018-01-01 23:59:36;read;country_6;2458153053;... NaN NaN NaN NaN NaN
# 1793  2018-01-01 23:59:36;read;country_7;2458153054;... NaN NaN NaN NaN NaN
# 1794  2018-01-01 23:59:38;read;country_5;2458153055;... NaN NaN NaN NaN NaN
#
#        6  Unnamed: 7
# 0    NaN         NaN
# ...

# %%
# Out:
#      2018-01-01 00:01:01;read;country_7;2458151261;SEO;North America
# 0     2018-01-01 00:03:20;read;country_7;2458151262;...
# 1     2018-01-01 00:04:01;read;country_7;2458151263;...
# 2     2018-01-01 00:04:02;read;country_7;2458151264;...
# 3     2018-01-01 00:05:03;read;country_8;2458151265;...
# 4     2018-01-01 00:05:42;read;country_6;2458151266;...
# ...                                                 ...
# 1789  2018-01-01 23:57:14;read;country_2;2458153051;...
# 1790  2018-01-01 23:58:33;read;country_8;2458153052;...
# 1791  2018-01-01 23:59:36;read;country_6;2458153053;...
# 1792  2018-01-01 23:59:36;read;country_7;2458153054;...
# 1793  2018-01-01 23:59:38;read;country_5;2458153055;...
#
# [1794 rows x 1 columns]

# %%
df
# Out:
#      2018-01-01 00:01:01;read;country_7;2458151261;SEO;North America
# 0     2018-01-01 00:03:20;read;country_7;2458151262;...
# 1     2018-01-01 00:04:01;read;country_7;2458151263;...
# 2     2018-01-01 00:04:02;read;country_7;2458151264;...
# 3     2018-01-01 00:05:03;read;country_8;2458151265;...
# 4     2018-01-01 00:05:42;read;country_6;2458151266;...
# ...                                                 ...
# 1789  2018-01-01 23:57:14;read;country_2;2458153051;...
# 1790  2018-01-01 23:58:33;read;country_8;2458153052;...
# 1791  2018-01-01 23:59:36;read;country_6;2458153053;...
# 1792  2018-01-01 23:59:36;read;country_7;2458153054;...
# 1793  2018-01-01 23:59:38;read;country_5;2458153055;...
#
# [1794 rows x 1 columns]
